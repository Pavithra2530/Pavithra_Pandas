# %% [markdown]
# <a href="https://colab.research.google.com/github/Pavithra2530/Pavithra_Pandas/blob/main/Pavithra_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd              #1

# %%
import numpy as np

# %%
pd. __version__                    #2
# Out:
# '1.3.5'

# %%
pd.show_versions()                   #3
# Out:
# INSTALLED VERSIONS
# ------------------
# commit           : 66e3805b8cabe977f40c05259cc3fcf7ead5687d
# python           : 3.8.16.final.0
# python-bits      : 64
# OS               : Linux
# OS-release       : 5.10.133+
# Version          : #1 SMP Fri Aug 26 08:44:51 UTC 2022
# machine          : x86_64
# processor        : x86_64
# byteorder        : little
# LC_ALL           : None
# LANG             : en_US.UTF-8
# LOCALE           : en_US.UTF-8
#
# pandas           : 1.3.5
# numpy            : 1.21.6
# pytz             : 2022.6
# dateutil         : 2.8.2
# pip              : 21.1.3
# setuptools       : 57.4.0
# Cython           : 0.29.32
# pytest           : 3.6.4
# hypothesis       : None
# sphinx           : 1.8.6
# blosc            : None
# feather          : 0.4.1
# xlsxwriter       : None
# lxml.etree       : 4.9.2
# html5lib         : 1.0.1
# pymysql          : None
# psycopg2         : 2.9.5 (dt dec pq3 ext lo64)
# jinja2           : 2.11.3
# IPython          : 7.9.0
# ...

# %%
data = {'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
        'age': [2.5, 3, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
        'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

# %%
df = pd.DataFrame(data, index=labels)                            #4

# %%
df.info()                                    #5
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, a to j
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   animal    10 non-null     object
#  1   age       8 non-null      float64
#  2   visits    10 non-null     int64
#  3   priority  10 non-null     object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 400.0+ bytes

# %%
df.iloc[:3]                                     #6
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no

# %%
df.loc[:, ['animal', 'age']]                                                             #7
# Out:
#   animal  age
# a    cat  2.5
# b    cat  3.0
# c  snake  0.5
# d    dog  NaN
# e    dog  5.0
# f    cat  2.0
# g  snake  4.5
# h    cat  NaN
# i    dog  7.0
# j    dog  3.0

# %%
df.loc[df.index [[3,4,8]], ['animal', 'age']]                    #8
# Out:
#   animal  age
# d    dog  NaN
# e    dog  5.0
# i    dog  7.0

# %%
df[df['visits'] > 3]                                 #9
# Out:
# Empty DataFrame
# Columns: [animal, age, visits, priority]
# Index: []

# %%
df[df['age'].isnull()]              #10
# Out:
#   animal  age  visits priority
# d    dog  NaN       3      yes
# h    cat  NaN       1      yes

# %%
df[(df['animal'] == 'cat') & (df['age'] < 3)]                  #11
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# f    cat  2.0       3       no

# %%
df[(df['age']).between(2,4)]                          #12
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# f    cat  2.0       3       no
# j    dog  3.0       1       no

# %%
df.loc['f','age'] = 1.5    #13
df.loc['f' ,'age']
# Out:
# 1.5

# %%
df['visits'].sum()           #14
# Out:
# 19

# %%
df.groupby('animal')['age'].mean()                     #15
# Out:
# animal
# cat      2.333333
# dog      5.000000
# snake    2.500000
# Name: age, dtype: float64

# %%
#16 adding k row
df.loc['k'] = ['dog', 3.5, 3, 'yes']                
df.loc['k']
# Out:
# animal      dog
# age         3.5
# visits        3
# priority    yes
# Name: k, dtype: object

# %%
removing k row
df.drop('k')
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  1.5       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %%
df['animal'].value_counts()                   #17
# Out:
# dog      5
# cat      4
# snake    2
# Name: animal, dtype: int64

# %%
df.sort_values(by=['age', 'visits'], ascending=[False, True])                              #18
# Out:
#   animal  age  visits priority
# i    dog  7.0       2       no
# e    dog  5.0       2       no
# g  snake  4.5       1       no
# k    dog  3.5       3      yes
# j    dog  3.0       1       no
# b    cat  3.0       3      yes
# a    cat  2.5       1      yes
# f    cat  1.5       3       no
# c  snake  0.5       2       no
# h    cat  NaN       1      yes
# d    dog  NaN       3      yes

# %%
df['priority'] = df['priority'].map({'yes': True, 'no': False})                   #19
df
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      NaN
# b    cat  3.0       3      NaN
# c  snake  0.5       2      NaN
# d    dog  NaN       3      NaN
# e    dog  5.0       2      NaN
# f    cat  1.5       3      NaN
# g  snake  4.5       1      NaN
# h    cat  NaN       1      NaN
# i    dog  7.0       2      NaN
# j    dog  3.0       1      NaN
# k    dog  3.5       3      NaN

# %%
df['animal'] = df['animal'].replace('snake' , 'python')                      #20
df
# Out:
#    animal  age  visits priority
# a     cat  2.5       1      NaN
# b     cat  3.0       3      NaN
# c  python  0.5       2      NaN
# d     dog  NaN       3      NaN
# e     dog  5.0       2      NaN
# f     cat  1.5       3      NaN
# g  python  4.5       1      NaN
# h     cat  NaN       1      NaN
# i     dog  7.0       2      NaN
# j     dog  3.0       1      NaN
# k     dog  3.5       3      NaN

# %%
df.pivot_table ( index ='animal', columns = 'visits' , values = 'age', aggfunc = 'mean')              #21
# Out:
# visits    1    2     3
# animal
# cat     2.5  NaN  2.25
# dog     3.0  6.0  3.50
# python  4.5  0.5   NaN

# %%
df = pd.DataFrame({'A': [1, 2, 2, 3, 4, 5, 5, 5, 6, 7, 7]})                                 #22
df.loc[df['A'].shift() !=df['A']]
# Out:
#    A
# 0  1
# 1  2
# 3  3
# 4  4
# 5  5
# 8  6
# 9  7

# %%
df = pd.DataFrame(np.random.random(size=(5, 3))) # a 5x3 frame of float values              #23
df.sub(df.mean(axis=1), axis =0)
# Out:
#           0         1         2
# 0  0.301717  0.031850 -0.333567
# 1 -0.251557  0.221551  0.030006
# 2 -0.207523 -0.105114  0.312637
# 3 -0.005638 -0.004906  0.010544
# 4  0.023142  0.132746 -0.155887

# %%
df = pd.DataFrame(np.random.random(size=(5, 10)), columns=list('abcdefghij'))               #24
df.sum().idxmin()
# Out:
# 'i'

# %%
df = pd.DataFrame(np.random.randint(0, 2, size=(10, 3)))                                    #25

len(df) - df.duplicated(keep=False).sum()
# Out:
# 0

# %%
nan = np.nan                                                                                  #26

data = [[0.04,  nan,  nan, 0.25,  nan, 0.43, 0.71, 0.51,  nan,  nan],
        [ nan,  nan,  nan, 0.04, 0.76,  nan,  nan, 0.67, 0.76, 0.16],
        [ nan,  nan, 0.5 ,  nan, 0.31, 0.4 ,  nan,  nan, 0.24, 0.01],
        [0.49,  nan,  nan, 0.62, 0.73, 0.26, 0.85,  nan,  nan,  nan],
        [ nan,  nan, 0.41,  nan, 0.05,  nan, 0.61,  nan, 0.48, 0.68]]

columns = list('abcdefghij')

df = pd.DataFrame(data, columns=columns)


(df.isnull().cumsum(axis=1) == 3).idxmax(axis=1)
# Out:
# 0    e
# 1    c
# 2    d
# 3    h
# 4    d
# dtype: object

# %%
df = pd.DataFrame({'grps': list('aaabbcaabcccbbc'),                                  #27
                   'vals': [12,345,3,1,45,14,4,52,54,23,235,21,57,3,87]})
df.groupby('grps')['vals'].nlargest(3).sum(level=0)
# Out:
# <ipython-input-10-6e1994ca69b0>:3: FutureWarning: Using the level keyword in DataFrame and Series aggregations is deprecated and will be removed in a future version. Use groupby instead. df.sum(level=1) should use df.groupby(level=1).sum().
#   df.groupby('grps')['vals'].nlargest(3).sum(level=0)
# grps
# a    409
# b    156
# c    345
# Name: vals, dtype: int64

# %%
df = pd.DataFrame(np.random.RandomState(8765).randint(1, 101, size=(100, 2)), columns = ["A", "B"])             #28
df.groupby(pd.cut(df['A'], np.arange(0, 101, 10)))['B'].sum()
# Out:
# A
# (0, 10]      635
# (10, 20]     360
# (20, 30]     315
# (30, 40]     306
# (40, 50]     750
# (50, 60]     284
# (60, 70]     424
# (70, 80]     526
# (80, 90]     835
# (90, 100]    852
# Name: B, dtype: int64

# %%
df = pd.DataFrame({'X': [7, 2, 0, 3, 4, 2, 5, 0, 3, 4]})                       #29

x = (df['X'] != 0).cumsum()
y = x != x.shift()
df['Y'] = y.groupby((y != y.shift()).cumsum()).cumsum()
df
# Out:
#    X  Y
# 0  7  1
# 1  2  2
# 2  0  0
# 3  3  1
# 4  4  2
# 5  2  3
# 6  5  4
# 7  0  0
# 8  3  1
# 9  4  2

# %%
df = pd.DataFrame(np.random.RandomState(30).randint(1, 101, size=(8, 8)))              #30
df.unstack().sort_values()[-3:].index.tolist()
# Out:
# [(5, 7), (6, 4), (2, 5)]

# %%
df = pd.DataFrame({"vals": np.random.RandomState(31).randint(-30, 30, size=15),             #31
                   "grps": np.random.RandomState(31).choice(["A", "B"], 15)})
def replace(group):
    mask = group<0
    group[mask] = group[~mask].mean()
    return group
df.groupby(['grps'])['vals'].transform(replace)
# Out:
# 0     13.6
# 1     28.0
# 2     13.6
# 3      4.0
# 4     13.6
# 5     28.0
# 6     13.6
# 7     13.6
# 8      8.0
# 9     28.0
# 10    28.0
# 11    12.0
# 12    16.0
# 13    13.6
# 14    13.6
# Name: vals, dtype: float64

# %%
df = pd.DataFrame({'group': list('aabbabbbabab'),                              #32
                   'value': [1, 2, 3, np.nan, 2, 3, np.nan, 1, 7, 3, np.nan, 8]})
g1 = df.groupby(['group'])['value']                
g2 = df.fillna(0).groupby(['group'])['value']
s= g2.rolling(3, min_periods=1).sum() / g1.rolling(3, min_periods=1).count()
s.reset_index(level=0, drop=True).sort_index()
# Out:
# 0     1.000000
# 1     1.500000
# 2     3.000000
# 3     3.000000
# 4     1.666667
# 5     3.000000
# 6     3.000000
# 7     2.000000
# 8     3.666667
# 9     2.000000
# 10    4.500000
# 11    4.000000
# Name: value, dtype: float64

# %%
dti = pd.date_range(start='2015-01-01', end='2015-12-31', freq='B')                  #33
s = pd.Series(np.random.rand(len(dti)), index=dti)
s
# Out:
# 2015-01-01    0.172087
# 2015-01-02    0.689847
# 2015-01-05    0.797685
# 2015-01-06    0.994590
# 2015-01-07    0.514191
#                 ...
# 2015-12-25    0.671232
# 2015-12-28    0.138461
# 2015-12-29    0.643259
# 2015-12-30    0.357203
# 2015-12-31    0.363606
# Freq: B, Length: 261, dtype: float64

# %%
s[s.index.weekday == 2].sum()                            #34
# Out:
# 23.565437417823965

# %%
s.resample('M').mean()                                    #35
# Out:
# 2015-01-31    0.521921
# 2015-02-28    0.467449
# 2015-03-31    0.436356
# 2015-04-30    0.533993
# 2015-05-31    0.470459
# 2015-06-30    0.480387
# 2015-07-31    0.543323
# 2015-08-31    0.525234
# 2015-09-30    0.337617
# 2015-10-31    0.456206
# 2015-11-30    0.607914
# 2015-12-31    0.562762
# Freq: M, dtype: float64

# %%
s.groupby(pd.Grouper(freq='4M')).idxmax()                          #36
# Out:
# 2015-01-31   2015-01-06
# 2015-05-31   2015-02-27
# 2015-09-30   2015-06-19
# 2016-01-31   2015-11-30
# Freq: 4M, dtype: datetime64[ns]

# %%
pd.date_range('2015-01-01', '2016-12-31', freq='WOM-3THU')                 #37
# Out:
# DatetimeIndex(['2015-01-15', '2015-02-19', '2015-03-19', '2015-04-16',
#                '2015-05-21', '2015-06-18', '2015-07-16', '2015-08-20',
#                '2015-09-17', '2015-10-15', '2015-11-19', '2015-12-17',
#                '2016-01-21', '2016-02-18', '2016-03-17', '2016-04-21',
#                '2016-05-19', '2016-06-16', '2016-07-21', '2016-08-18',
#                '2016-09-15', '2016-10-20', '2016-11-17', '2016-12-15'],
#               dtype='datetime64[ns]', freq='WOM-3THU')

# %%
df = pd.DataFrame({'From_To': ['LoNDon_paris', 'MAdrid_miLAN', 'londON_StockhOlm', 
                               'Budapest_PaRis', 'Brussels_londOn'],
              'FlightNumber': [10045, np.nan, 10065, np.nan, 10085],
              'RecentDelays': [[23, 47], [], [24, 43, 87], [13], [67, 32]],
                   'Airline': ['KLM(!)', '<Air France> (12)', '(British Airways. )', 
                               '12. Air France', '"Swiss Air"']})

# %%
df['FlightNumber'] = df['FlightNumber'].interpolate().astype(int)                     #38
df
# Out:
#             From_To  FlightNumber  RecentDelays              Airline
# 0      LoNDon_paris         10045      [23, 47]               KLM(!)
# 1      MAdrid_miLAN         10055            []    <Air France> (12)
# 2  londON_StockhOlm         10065  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis         10075          [13]       12. Air France
# 4   Brussels_londOn         10085      [67, 32]          "Swiss Air"

# %%
temp = df.From_To.str.split('_', expand=True)                                   #39
temp.columns = ['From', 'To']
temp
# Out:
#        From         To
# 0    LoNDon      paris
# 1    MAdrid      miLAN
# 2    londON  StockhOlm
# 3  Budapest      PaRis
# 4  Brussels     londOn

# %%
temp['From'] = temp['From'].str.capitalize()                                #40
temp['To'] = temp['To'].str.capitalize()
temp
# Out:
#        From         To
# 0    London      Paris
# 1    Madrid      Milan
# 2    London  Stockholm
# 3  Budapest      Paris
# 4  Brussels     London

# %%
df = df.drop('From_To', axis=1)                                          #41
df = df.join(temp) 
df
# Out:
#    FlightNumber  RecentDelays              Airline      From         To
# 0         10045      [23, 47]               KLM(!)    London      Paris
# 1         10055            []    <Air France> (12)    Madrid      Milan
# 2         10065  [24, 43, 87]  (British Airways. )    London  Stockholm
# 3         10075          [13]       12. Air France  Budapest      Paris
# 4         10085      [67, 32]          "Swiss Air"  Brussels     London

# %%
df['Airline'] = df['Airline'].str.extract('([a-zA-Z\s]+)', expand=False).str.strip()              #42
df
# Out:
#    FlightNumber  RecentDelays          Airline      From         To
# 0         10045      [23, 47]              KLM    London      Paris
# 1         10055            []       Air France    Madrid      Milan
# 2         10065  [24, 43, 87]  British Airways    London  Stockholm
# 3         10075          [13]       Air France  Budapest      Paris
# 4         10085      [67, 32]        Swiss Air  Brussels     London

# %%
delays = df['RecentDelays'].apply(pd.Series)                                               #43
delays.columns = ['delay_{}'.format(n) for n in range(1, len(delays.columns)+1)]
df = df.drop('RecentDelays', axis=1).join(delays)
df
# Out:
#    FlightNumber          Airline      From         To  delay_1  delay_2  \
# 0         10045              KLM    London      Paris     23.0     47.0
# 1         10055       Air France    Madrid      Milan      NaN      NaN
# 2         10065  British Airways    London  Stockholm     24.0     43.0
# 3         10075       Air France  Budapest      Paris     13.0      NaN
# 4         10085        Swiss Air  Brussels     London     67.0     32.0
#
#    delay_3
# 0      NaN
# 1      NaN
# 2     87.0
# 3      NaN
# 4      NaN

# %%
letters = ['A', 'B', 'C']                                                        #44
numbers = list(range(10))
mi = pd.MultiIndex.from_product([letters, numbers])
s = pd.Series(np.random.rand(30), index=mi)
s
# Out:
# A  0    0.888143
#    1    0.768927
#    2    0.219957
#    3    0.339467
#    4    0.010066
#    5    0.299166
#    6    0.045859
#    7    0.981507
#    8    0.702466
#    9    0.532920
# B  0    0.218431
#    1    0.830855
#    2    0.891466
#    3    0.402202
#    4    0.141822
#    5    0.305822
#    6    0.744172
#    7    0.602070
#    8    0.770656
#    9    0.211562
# C  0    0.123987
#    1    0.739984
#    2    0.357369
#    3    0.290563
#    4    0.832972
#    5    0.535847
#    6    0.510127
#    7    0.515006
#    8    0.793292
#    9    0.914823
# dtype: float64

# %%
s.index.lexsort_depth == s.index.nlevels                                #45
# Out:
# <ipython-input-41-11e5fbbcfcac>:1: FutureWarning: MultiIndex.is_lexsorted is deprecated as a public function, users should use MultiIndex.is_monotonic_increasing instead.
#   s.index.lexsort_depth == s.index.nlevels
# True

# %%
s.loc[:, [1, 3, 6]]                             #46
# Out:
# A  1    0.768927
#    3    0.339467
#    6    0.045859
# B  1    0.830855
#    3    0.402202
#    6    0.744172
# C  1    0.739984
#    3    0.290563
#    6    0.510127
# dtype: float64

# %%
s.loc[pd.IndexSlice[:'B', 5:]]                         #47
# Out:
# A  5    0.299166
#    6    0.045859
#    7    0.981507
#    8    0.702466
#    9    0.532920
# B  5    0.305822
#    6    0.744172
#    7    0.602070
#    8    0.770656
#    9    0.211562
# dtype: float64

# %%
s.sum(level=0)                                          #48
# Out:
# <ipython-input-44-033d2552e0bd>:1: FutureWarning: Using the level keyword in DataFrame and Series aggregations is deprecated and will be removed in a future version. Use groupby instead. df.sum(level=1) should use df.groupby(level=1).sum().
#   s.sum(level=0)                                          #48
# A    4.788477
# B    5.119059
# C    5.613968
# dtype: float64

# %%
s.unstack().sum(axis=0)                      #49
# Out:
# 0    1.230561
# 1    2.339766
# 2    1.468792
# 3    1.032232
# 4    0.984860
# 5    1.140835
# 6    1.300157
# 7    2.098583
# 8    2.266414
# 9    1.659304
# dtype: float64

# %%
new_s = s.swaplevel(0, 1)                                        #50

if not new_s.index.is_lexsorted():
    new_s = new_s.sort_index()

new_s
# Out:
# <ipython-input-46-5cf5d39845f2>:3: FutureWarning: MultiIndex.is_lexsorted is deprecated as a public function, users should use MultiIndex.is_monotonic_increasing instead.
#   if not new_s.index.is_lexsorted():
# 0  A    0.888143
#    B    0.218431
#    C    0.123987
# 1  A    0.768927
#    B    0.830855
#    C    0.739984
# 2  A    0.219957
#    B    0.891466
#    C    0.357369
# 3  A    0.339467
#    B    0.402202
#    C    0.290563
# 4  A    0.010066
#    B    0.141822
#    C    0.832972
# 5  A    0.299166
#    B    0.305822
#    C    0.535847
# 6  A    0.045859
#    B    0.744172
#    C    0.510127
# 7  A    0.981507
#    B    0.602070
#    C    0.515006
# 8  A    0.702466
#    B    0.770656
#    C    0.793292
# 9  A    0.532920
#    B    0.211562
#    C    0.914823
# dtype: float64

# %%
X = 5                                                          #51
Y = 4

p = pd.core.reshape.util.cartesian_product([np.arange(X), np.arange(Y)])
df = pd.DataFrame(np.asarray(p).T, columns=['x', 'y'])
df
# Out:
#     x  y
# 0   0  0
# 1   0  1
# 2   0  2
# 3   0  3
# 4   1  0
# 5   1  1
# 6   1  2
# 7   1  3
# 8   2  0
# 9   2  1
# 10  2  2
# 11  2  3
# 12  3  0
# 13  3  1
# 14  3  2
# 15  3  3
# 16  4  0
# 17  4  1
# 18  4  2
# 19  4  3

# %%
df['mine'] = np.random.binomial(1, 0.4, X*Y)                                #52
df
# Out:
#     x  y  mine
# 0   0  0     1
# 1   0  1     0
# 2   0  2     1
# 3   0  3     0
# 4   1  0     1
# 5   1  1     1
# 6   1  2     1
# 7   1  3     0
# 8   2  0     1
# 9   2  1     0
# 10  2  2     1
# 11  2  3     0
# 12  3  0     0
# 13  3  1     0
# 14  3  2     0
# 15  3  3     1
# 16  4  0     1
# 17  4  1     0
# 18  4  2     0
# 19  4  3     0

# %%
from scipy.signal import convolve2d                                           #53

mine_grid = df.pivot_table(columns='x', index='y', values='mine')
counts = convolve2d(mine_grid.astype(complex), np.ones((3, 3)), mode='same').real.astype(int)
df['adjacent'] = (counts - mine_grid).ravel('F')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-1f9fbf0267d0> in <module>
#       3 mine_grid = df.pivot_table(columns='x', index='y', values='mine')
#       4 counts = convolve2d(mine_grid.astype(complex), np.ones((3, 3)), mode='same').real.astype(int)
# ----> 5 df['adjacent'] = (counts - mine_grid).ravel('F')
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'ravel'

# %%
df.loc[df['mine'] == 1, 'adjacent'] = np.nan                                    #54
df
# Out:
#     x  y  mine  adjacent
# 0   0  0     1       NaN
# 1   0  1     0       5.0
# 2   0  2     1       NaN
# 3   0  3     0       2.0
# 4   1  0     1       NaN
# 5   1  1     1       NaN
# 6   1  2     1       NaN
# 7   1  3     0       3.0
# 8   2  0     1       NaN
# 9   2  1     0       5.0
# 10  2  2     1       NaN
# 11  2  3     0       3.0
# 12  3  0     0       2.0
# 13  3  1     0       3.0
# 14  3  2     0       2.0
# 15  3  3     1       NaN
# 16  4  0     1       NaN
# 17  4  1     0       1.0
# 18  4  2     0       1.0
# 19  4  3     0       1.0

# %%
df.drop('mine', axis=1).set_index(['y', 'x']).unstack()                   #55
# Out:
#   adjacent
# x        0    1    2    3    4
# y
# 0      NaN  NaN  NaN  2.0  NaN
# 1      5.0  NaN  5.0  3.0  1.0
# 2      NaN  NaN  NaN  2.0  1.0
# 3      2.0  3.0  3.0  NaN  1.0

# %%
import matplotlib.pyplot as plt                                          #56
# %matplotlib inline
plt.style.use('ggplot')
df = pd.DataFrame({"xs":[1,5,2,8,1], "ys":[4,2,1,9,6]})
df.plot.scatter("xs", "ys", color = "black", marker = "x")

# %%
df = pd.DataFrame({"productivity":[5,2,3,1,4,5,6,7,8,3,4,8,9],                      #57
                   "hours_in"    :[1,9,6,5,3,9,2,9,1,7,4,2,2],
                   "happiness"   :[2,1,3,2,3,1,2,3,1,2,2,1,3],
                   "caffienated" :[0,0,1,1,0,0,0,0,1,1,0,1,0]})
df.plot.scatter("hours_in", "productivity", s = df.happiness * 30, c = df.caffienated)

# %%
df = pd.DataFrame({"revenue":[57,68,63,71,72,90,80,62,59,51,47,52],                    #58
                   "advertising":[2.1,1.9,2.7,3.0,3.6,3.2,2.7,2.4,1.8,1.6,1.3,1.9],
                   "month":range(12) })
ax = df.plot.bar("month", "revenue", color = "green")
df.plot.line("month", "advertising", secondary_y = True, ax = ax)
ax.set_xlim((-1,12))
# Out:
# (-1.0, 12.0)

# %%
def float_to_time(x):
    return str(int(x)) + ":" + str(int(x%1 * 60)).zfill(2) + ":" + str(int(x*60 % 1 * 60)).zfill(2)

def day_stock_data():
    #NYSE is open from 9:30 to 4:00
    time = 9.5
    price = 100
    results = [(float_to_time(time), price)]
    while time < 16:
        elapsed = np.random.exponential(.001)
        time += elapsed
        if time > 16:
            break
        price_diff = np.random.uniform(.999, 1.001)
        price *= price_diff
        results.append((float_to_time(time), price))
    
    
    df = pd.DataFrame(results, columns = ['time','price'])
    df.time = pd.to_datetime(df.time)
    return df

def plot_candlestick(agg):
    fig, ax = plt.subplots()
    for time in agg.index:
        ax.plot([time.hour] * 2, agg.loc[time, ["high","low"]].values, color = "black")
        ax.plot([time.hour] * 2, agg.loc[time, ["open","close"]].values, color = agg.loc[time, "color"], linewidth = 10)

    ax.set_xlim((8,16))
    ax.set_ylabel("Price")
    ax.set_xlabel("Hour")
    ax.set_title("OHLC of Stock Value During Trading Day")
    plt.show()

# %%
df = day_stock_data()                                        #59
df.head()
# Out:
#                  time       price
# 0 2023-01-06 09:30:00  100.000000
# 1 2023-01-06 09:30:03  100.076047
# 2 2023-01-06 09:30:10  100.138461
# 3 2023-01-06 09:30:11  100.127237
# 4 2023-01-06 09:30:14  100.190410

# %%
df.set_index("time", inplace = True)                        #59
agg = df.resample("H").ohlc()
agg.columns = agg.columns.droplevel()
agg["color"] = (agg.close > agg.open).map({True:"green",False:"red"})
agg.head()
# Out:
#                            open        high         low       close  color
# time
# 2023-01-06 09:00:00  100.000000  102.736449  100.000000  101.907329  green
# 2023-01-06 10:00:00  101.986211  102.307722  100.369964  101.313018    red
# 2023-01-06 11:00:00  101.272751  103.744305  100.227095  102.767648  green
# 2023-01-06 12:00:00  102.751510  103.813860  101.130281  103.193709  green
# 2023-01-06 13:00:00  103.200237  106.509881  102.821503  105.051017  green

# %%
plot_candlestick(agg)                              #60
